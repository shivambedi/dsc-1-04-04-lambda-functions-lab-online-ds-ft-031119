# %% [markdown]
# # Lambda Functions - Lab

# %% [markdown]
# ## Introduction|
#
# In this lab, you'll get some hands on practice creating and using lambda functions.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Understand what lambda functions are and why they are useful
# * Use lambda functions to transform data within lists and DataFrames

# %% [markdown]
# ## Lambda Functions

# %%
import pandas as pd
df = pd.read_csv('Yelp_Reviews.csv')
df.head(210)
# Out:
#      Unnamed: 0             business_id  cool        date  funny  \
# 0             1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0
# 1             2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1
# 2             4  Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0
# 3             5  vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0
# 4            10  yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0
# 5            11  UBv8heCQR0RPnUQG0zkXIQ     0  2016-09-23      0
# 6            12  hdgYnadxg0GANhWOJabr2g     0  2014-08-23      0
# 7            19  gZGsReG0VeX4uKViHTB9EQ     0  2017-08-16      0
# 8            25  f-v1fvtnbdw_QQRsCnwH-g     0  2017-11-18      0
# 9            26  yz66FIUPDKGhILDWzRLeKg     0  2017-11-18      0
# 10           27  6qDRqHWqf0EeHupSUEBfKg     0  2015-12-10      0
# 11           28  7AlULGZI1pHt0imODsqdkg     0  2012-02-12      0
# 12           29  th4pZ5LkoIIkb1Vmu_m2DA     0  2012-02-12      0
# 13           30  nsSfCKW9KDB4COj9bzXApw     0  2012-02-12      0
# 14           31  cP8ErpZfRzdVR5Fvks-pnQ     0  2012-02-12      0
# 15           32  Edr6SafmQrZa6CcFuItoqg     0  2014-06-03      0
# 16           35  SpJYus_184M2TdT7t52rIA     0  2016-11-18      0
# 17           40  qdC2h3MqCNussc5lhzL7gg     0  2015-11-05      0
# 18           41  XgRDG9E_WLEbl8S-QUqQkQ     0  2015-11-05      0
# 19           42  awgoBwuhzlLGKEIverTGjQ     0  2017-01-21      0
# 20           74  iO3GuIiZxzv-iETGVnoeVA     0  2016-11-06      0
# 21           79  yz3KtngrF2PQrif8JW7gdw     0  2016-05-28      0
# 22           83  T2XdzAcj0M_kBD9_BHfZlw     0  2016-05-08      0
# 23           92  AtbXj3Rg1GF6Dj5zu6KCDg     0  2012-10-11      0
# 24           95  6tSvz_21BMo3a4GaItwa0g     0  2017-04-08      0
# 25          102  aQ222ydz_GSRZV66xNt4kQ     0  2017-04-09      1
# 26          172  1SnYDvrd02FXSXnIgz-9DQ     0  2010-11-17      4
# 27          179  YPa8t1631tlRQms0p331ZQ     0  2016-04-10      0
# 28          180  eZCE1u_3ORlX8dHSVTjl9w     0  2016-03-10      1
# 29          182  ruWTngdiC68O9la27hvvHw     0  2016-02-24      0
# ..          ...                     ...   ...         ...    ...
# 180         666  IdNR_TYoB7eHz681M0bKag     0  2013-03-10      0
# 181         668  caXiL25g86LPvdwbn99VgA     0  2012-07-02      0
# 182         670  gTaD9vJp04nFJBWyX7eK7Q     0  2013-06-02      2
# 183         672  2iLeiQ4OCJVwfodR9egMag     1  2013-03-19      0
# 184         674  jpBOoa3qNwsbVkdS2cdYSg     0  2013-07-28      0
# 185         675  GYTmQ4LK7vssENFDBuUt3w     1  2016-10-12      1
# 186         676  eMvikXS_1HlPyVctesxSjA     0  2017-06-07      0
# 20   RW_mYzHYfdqn6g7xVgIcKg      4
# 21   SLA1YP9doUc8h-6Kd34QmA      1
# 22   qxPiEGIHy5xyVy78avH5Rg      4
# 23   q6ij-nz5d_hvdjuelho1pQ      5
# 24   66FSK2J1uHJqVI1Z8QiFGw      4
# 25   AxhxGl41DItKjqkzYtr53Q      1
# 26   8enQ9Fj-sWkWub4AZQUzeQ      1
# 27   vCwlUF30mV7Eg5MCS3N39Q      4
# 28   GuD3Og1PmJCqXAiWQe1xew      4
# 29   Tifm4ETlt4FXiuGwhq__lg      4
# ..                      ...    ...
# 180  XuSie_006DeLXVNCLPM8-g      4
# 181  wfMmujCs8Y7H8XzuXJ8odA      5
# 182  AoxpOFSlVq3mIbfonPhY3A      5
# 183  VlUZG5zA-VrIN76wLyh0_g      4
# 184  pwQZaBj36_DgN1dWIdZKwA      4
# 185  ECzqFLPc19OSZ4Sf2YqRdA      5
# 186  _sirto2dSokkNdPcxRcaXA      5
# 187  -_JK9H545H8SZuOJZpdlmg      3
# 188  Vhvs1s3DHtIykDUWiXCwWw      4
# 189  s3AkOkFhe-nzEkR5N1V0JA      4
# 190  1v5ecsrr-38Vzup5aR40kQ      4
# 191  HQngKUrerDSj_l0Suq-7sw      5
# 192  cNQ5AlAhZmwFFlurZtgOww      4
# 193  9FMtFHT01G1xaI2I4CEtJA      5
# 194  9xtSmbEK-mG_Nl8gF0vn1g      5
# 195  0QsCkd0MWH1xurDMqWjevQ      3
# 196  qUKj7zIA1gJq3KW_pIkv6g      5
# 197  7jYLdFeS2d8dx0ZOaiId-g      3
# 198  fyVtCd2QlFxtVdtEFnu8Xw      4
# 199  dfa66f-q8ddn97B4Cw96kg      3
# 200  sZsyHJQvluH2dck_0lqarw      4
# 201  vMEfCyisYZl8RWRDtfeP5g      4
# 202  7J3swG3oMdGYuUCIgFsfRw      5
# 203  3FUYVgTPwB0GJwEPnGidog      5
# 204  1-RDYuXP-Fch8Vdmy4g-WA      5
# 205  0Gt4cXuT7A0KZ_7nt-nU0g      4
# 206  bKOvYg4vMVSjxYIwHUPQbQ      4
# 207  p9qeAnI-Di9WFqlu_LREuA      5
# 208  nTf7s720IRC6bweUyFXZuA      5
# 209  R9fs85b354hXFU3Q-phHfw      5
#
#                                                   text  useful  \
# 0    I love this place! My fiance And I go here atl...       0
# 1    Terrible. Dry corn bread. Rib tips were all fa...       3
# 2    Delicious healthy food. The steak is amazing. ...       0
# 3    This place sucks. The customer service is horr...       2
# 4    I have been an Emerald Club member for a numbe...       0
# 5    The score should be negative. Its HORRIBLE. Th...       0
# 6    I went there twice and I am pretty happy with ...       0
# 7    Finally! After trying many Mexican restaurants...       0
# 8    I have to write a review on the Fractured Prun...       0
# 9    I wish i could tell you all about the food but...       1
# 10   Wonderful! One of my favorite places. BBQ is e...       0
# 11   The price is about the same as Quizinos. The s...       0
# 12   The food was ok. You get a lot of food for the...       0
# 11   FjH3TH8OvHGLNEbzdEYlNg
# 12   FjH3TH8OvHGLNEbzdEYlNg
# 13   FjH3TH8OvHGLNEbzdEYlNg
# 14   FjH3TH8OvHGLNEbzdEYlNg
# 15   B7Fh30KQT1xPSGt_pIhRRA
# 16   zx_Op2OAOM_fRic9tU-jqA
# 17   Ka7TIp74VHSa90rfdg4_2g
# 18   Ka7TIp74VHSa90rfdg4_2g
# 19   yyPHK6khPa4-ErV9U32x3A
# 20   0pf5VuzE4_1pwj5NJHG5TQ
# 21   0pf5VuzE4_1pwj5NJHG5TQ
# 22   0pf5VuzE4_1pwj5NJHG5TQ
# 23   WnM2AmNIint5b5f688nmPg
# 24   Yy_iGXxLpL6tYDQoE-6XVg
# 25   Yy_iGXxLpL6tYDQoE-6XVg
# 26   YHWsLBS8jzZiPjKHMFOaAA
# 27   wMttR-7frrO-YzDsIiA4GQ
# 28   wMttR-7frrO-YzDsIiA4GQ
# 29   dQzQ4bN0Rnb8M-0LqTl3-g
# ..                      ...
# 180  q3AiAe-AcpDrNsdZf8nCvQ
# 181  q3AiAe-AcpDrNsdZf8nCvQ
# 182  q3AiAe-AcpDrNsdZf8nCvQ
# 183  q3AiAe-AcpDrNsdZf8nCvQ
# 184  q3AiAe-AcpDrNsdZf8nCvQ
# 185  q3AiAe-AcpDrNsdZf8nCvQ
# 186  q3AiAe-AcpDrNsdZf8nCvQ
# 187  q3AiAe-AcpDrNsdZf8nCvQ
# 188  q3AiAe-AcpDrNsdZf8nCvQ
# 189  q3AiAe-AcpDrNsdZf8nCvQ
# 190  q3AiAe-AcpDrNsdZf8nCvQ
# 191  q3AiAe-AcpDrNsdZf8nCvQ
# 192  q3AiAe-AcpDrNsdZf8nCvQ
# 193  q3AiAe-AcpDrNsdZf8nCvQ
# 194  q3AiAe-AcpDrNsdZf8nCvQ
# 195  q3AiAe-AcpDrNsdZf8nCvQ
# 196  q3AiAe-AcpDrNsdZf8nCvQ
# 197  q3AiAe-AcpDrNsdZf8nCvQ
# 198  q3AiAe-AcpDrNsdZf8nCvQ
# 199  q3AiAe-AcpDrNsdZf8nCvQ
# 200  q3AiAe-AcpDrNsdZf8nCvQ
# 201  q3AiAe-AcpDrNsdZf8nCvQ
# 202  q3AiAe-AcpDrNsdZf8nCvQ
# 203  q3AiAe-AcpDrNsdZf8nCvQ
# 204  WgbbxTRIy7MwDKn7nL5WKQ
# 205  WgbbxTRIy7MwDKn7nL5WKQ
# 206  WgbbxTRIy7MwDKn7nL5WKQ
# 207  WgbbxTRIy7MwDKn7nL5WKQ
# 208  qSnGTERljtADoOatQiekrg
# 209  HeK9vYCsGCcNddefnpepyg
#
# [210 rows x 10 columns]

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'business_id', 'cool', 'date', 'funny', 'review_id',
#        'stars', 'text', 'useful', 'user_id'], dtype=object)

# %% [markdown]
# # Simple Arithmetic
#
# Use a lambda function to create a new column called 'stars_squared' by squarring the stars column.

# %%
#building fucntion step by step
#stars_data=df['stars']
#stars_data=df['stars']**2
#stars_data
#df['stars_data_squared']=stars_data
#df.head()
#del df['stars_data_squared']
#df.head()

df['stars_squared'] = df.stars.map(lambda x: x**2)
df.head()
# Out:
#    Unnamed: 0             business_id  cool        date  funny  \
# 0           1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0
# 1           2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1
# 2           4  Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0
# 3           5  vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0
# 4          10  yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0
#
#                 review_id  stars  \
# 0  dDl8zu1vWPdKGihJrwQbpw      5
# 1  LZp4UX5zK3e-c5ZGSeo3kA      1
# 2  jsDu6QEJHbwP2Blom1PLCA      5
# 3  pfavA0hr3nyqO61oupj-lA      1
# 4  STiFMww2z31siPY7BWNC2g      5
#
#                                                 text  useful  \
# 0  I love this place! My fiance And I go here atl...       0
# 1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 2  Delicious healthy food. The steak is amazing. ...       0
# 3  This place sucks. The customer service is horr...       2
# 4  I have been an Emerald Club member for a numbe...       0
#
#                   user_id  stars_squared
# 0  msQe1u7Z_XuqjGoqhB0J5g             25
# 1  msQe1u7Z_XuqjGoqhB0J5g              1
# 2  msQe1u7Z_XuqjGoqhB0J5g             25
# 3  msQe1u7Z_XuqjGoqhB0J5g              1
# 4  TlvV-xJhmh7LCwJYXkV-cg             25

# %%
# Out:
#    Unnamed: 0             business_id  cool        date  funny  \
# 0           1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0
# 1           2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1
# 2           4  Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0
# 3           5  vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0
# 4          10  yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0
#
#                 review_id  stars  \
# 0  dDl8zu1vWPdKGihJrwQbpw      5
# 1  LZp4UX5zK3e-c5ZGSeo3kA      1
# 2  jsDu6QEJHbwP2Blom1PLCA      5
# 3  pfavA0hr3nyqO61oupj-lA      1
# 4  STiFMww2z31siPY7BWNC2g      5
#
#                                                 text  useful  \
# 0  I love this place! My fiance And I go here atl...       0
# 1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 2  Delicious healthy food. The steak is amazing. ...       0
# 3  This place sucks. The customer service is horr...       2
# 4  I have been an Emerald Club member for a numbe...       0
#
#                   user_id  stars_squared
# 0  msQe1u7Z_XuqjGoqhB0J5g             25
# 1  msQe1u7Z_XuqjGoqhB0J5g              1
# 2  msQe1u7Z_XuqjGoqhB0J5g             25
# 3  msQe1u7Z_XuqjGoqhB0J5g              1
# 4  TlvV-xJhmh7LCwJYXkV-cg             25

# %% [markdown]
# # Dates
# Select the month from the date string using a lambda function.

# %%
df.date.map(lambda x: x[5:-3]).head()
# Out:
# 0    11
# 1    10
# 2    09
# 3    02
# 4    06
# Name: date, dtype: object

# %% [markdown]
# # What is the average number of words for a yelp review?
# Do this with a single line of code!

# %%
#wl=df.text[0].split()#
#wl
#df.text.map(     lambda x: len(x.split()     )    ).mean()
df.text.map(lambda x: len(x.split())).mean()
# Out:
# 77.06551724137931

# %% [markdown]
# # Create a new column for the number of words in the review.

# %%
df['number_of_words'] = df.text.map(lambda x: len(x.split()))
df.head()
# Out:
#    Unnamed: 0             business_id  cool        date  funny  \
# 0           1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0
# 1           2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1
# 2           4  Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0
# 3           5  vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0
# 4          10  yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0
#
#                 review_id  stars  \
# 0  dDl8zu1vWPdKGihJrwQbpw      5
# 1  LZp4UX5zK3e-c5ZGSeo3kA      1
# 2  jsDu6QEJHbwP2Blom1PLCA      5
# 3  pfavA0hr3nyqO61oupj-lA      1
# 4  STiFMww2z31siPY7BWNC2g      5
#
#                                                 text  useful  \
# 0  I love this place! My fiance And I go here atl...       0
# 1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 2  Delicious healthy food. The steak is amazing. ...       0
# 3  This place sucks. The customer service is horr...       2
# 4  I have been an Emerald Club member for a numbe...       0
#
#                   user_id  number_of_words
# 0  msQe1u7Z_XuqjGoqhB0J5g               58
# 1  msQe1u7Z_XuqjGoqhB0J5g               30
# 2  msQe1u7Z_XuqjGoqhB0J5g               30
# 3  msQe1u7Z_XuqjGoqhB0J5g               82
# 4  TlvV-xJhmh7LCwJYXkV-cg               32

# %% [markdown]
# ## Rewrite the following as a lamda function. Create a new column 'Review_Length'

# %%
def rewrite_as_lambda(value):
    if len(value) < 50:
        return 'Short'
    elif len(value) < 80:
        return 'Medium'
    else:
        return 'Long'
#Hint: nest your if, else conditionals

# %%
# usingthe existing function and calling it as lmba function
#df['review_length'] = df.text.map(lambda review: rewrite_as_lambda(review) )
#df.head()

#using already created "number_of_words"column that relects the length of review words
df['Review_length'] = df['number_of_words'].map(lambda x: 'Short' if x < 50 else ('Medium' if x < 80 else 'Long'))
df.Review_length.value_counts(normalize=True)
# Out:
# Short     0.493103
# Long      0.294636
# Medium    0.212261
# Name: Review_length, dtype: float64

# %% [markdown]
# '# Level Up: Dates Adavanced!
# <img src="date_format_map.png" width=500>
#
# Overwrite the date column by reordering the month and day from YYYY-MM-DD to DD-MM-YYYY. Try to do this using a lambda function.

# %%
#Your code here

# %% [markdown]
# ## Summary
#
# Great! Hopefully you're getting the hang of lambda functions now! It's important not to overuse them - it will often make more sense to define a function so that it's reusable elsewhere. But whenever you need to quickly apply some simple processing to a collection of data you have a new technique that will help you to do just that. It'll also be useful if you're reading someone elses code that happens to use lambdas.
